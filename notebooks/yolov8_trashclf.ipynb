# %%
# !pip install -qq wandb roboflow
# !pip install ultralytics==8.2.103 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.1/875.1 kB 23.2 MB/s eta 0:00:00

# %%
import wandb
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !git clone https://github.com/InhumanlyInsane/trashnet-clf.git
# !pip install -r trashnet-clf/requirements.txt
# !python trashnet-clf/dataset_collection.py
# Out:
# Cloning into 'trashnet-clf'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (23/23), done.
# Receiving objects: 100% (35/35), 15.67 KiB | 15.67 MiB/s, done.
# remote: Total 35 (delta 13), reused 27 (delta 8), pack-reused 0 (from 0)
# Resolving deltas: 100% (13/13), done.
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 1)) (1.4.20)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 2)) (4.10.0.84)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 3)) (0.27.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 4)) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 5)) (0.20.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from -r trashnet-clf/requirements.txt (line 8)) (0.19.1)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations->-r trashnet-clf/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations->-r trashnet-clf/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations->-r trashnet-clf/requirements.txt (line 1)) (2.10.3)
# Requirement already satisfied: albucore==0.0.19 in /usr/local/lib/python3.10/dist-packages (from albumentations->-r trashnet-clf/requirements.txt (line 1)) (0.0.19)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.10/dist-packages (from albumentations->-r trashnet-clf/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations->-r trashnet-clf/requirements.txt (line 1)) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.19->albumentations->-r trashnet-clf/requirements.txt (line 1)) (3.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r trashnet-clf/requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r trashnet-clf/requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->-r trashnet-clf/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->-r trashnet-clf/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->-r trashnet-clf/requirements.txt (line 5)) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->-r trashnet-clf/requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r trashnet-clf/requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->-r trashnet-clf/requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (4.25.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (5.9.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (2.19.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (1.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->-r trashnet-clf/requirements.txt (line 8)) (75.1.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->-r trashnet-clf/requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r trashnet-clf/requirements.txt (line 8)) (4.0.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations->-r trashnet-clf/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations->-r trashnet-clf/requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r trashnet-clf/requirements.txt (line 3)) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r trashnet-clf/requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r trashnet-clf/requirements.txt (line 8)) (5.0.1)
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.23 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# dataset-resized.zip: 100% 42.8M/42.8M [00:00<00:00, 187MB/s]
# Augmenting glass class images 1 times each...
# 100% 400/400 [00:06<00:00, 61.96it/s]
# Augmenting cardboard class images 1 times each...
# 100% 322/322 [00:04<00:00, 68.48it/s]
# Augmenting metal class images 1 times each...
# 100% 328/328 [00:06<00:00, 53.55it/s]
# Augmenting plastic class images 1 times each...
# 100% 385/385 [00:05<00:00, 71.08it/s]
# Balanced data augmentation completed!

# %%
from ultralytics import YOLO
# !yolo task=classify mode=train model=yolov8s-cls.pt data=./data-main epochs=50 imgsz=512
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s-cls.pt to 'yolov8s-cls.pt'...
# 100% 12.3M/12.3M [00:00<00:00, 88.5MB/s]
# New https://pypi.org/project/ultralytics/8.3.52 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=classify, mode=train, model=yolov8s-cls.pt, data=./data-main, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train
# train: /content/data-main/train... found 3345 images in 5 classes ✅
# val: /content/data-main/val... found 480 images in 5 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    664325  ultralytics.nn.modules.head.Classify         [512, 5]
# YOLOv8s-cls summary: 99 layers, 5,087,141 parameters, 5,087,141 gradients, 12.6 GFLOPs
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train', view at http://localhost:6006/
# wandb: Currently logged in as: soyokaze83 (soyokaze83-universitas-indonesia). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /content/wandb/run-20241221_141506-6zlvahan
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train
# wandb: ⭐️ View project at https://wandb.ai/soyokaze83-universitas-indonesia/YOLOv8
# wandb: 🚀 View run at https://wandb.ai/soyokaze83-universitas-indonesia/YOLOv8/runs/6zlvahan
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 115MB/s]
# AMP: checks passed ✅
# train: Scanning /content/data-main/train... 3345 images, 0 corrupt: 100% 3345/3345 [00:00<00:00, 4088.32it/s]
# train: New cache created: /content/data-main/train.cache
# val: Scanning /content/data-main/val... 480 images, 0 corrupt: 100% 480/480 [00:00<00:00, 2455.99it/s]
# val: New cache created: /content/data-main/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 2 dataloader workers
# Logging results to runs/classify/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50      1.74G      1.668         16        512:   2% 5/210 [00:02<01:03,  3.24it/s]Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
#        1/50      1.94G      1.673         16        512:   3% 6/210 [00:03<02:02,  1.66it/s]
# 100% 755k/755k [00:00<00:00, 18.5MB/s]
#        1/50      1.96G      1.202          1        512: 100% 210/210 [01:30<00:00,  2.32it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:07<00:00,  1.92it/s]
#                    all       0.84          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50       1.8G     0.5979          1        512: 100% 210/210 [01:21<00:00,  2.57it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:07<00:00,  2.05it/s]
#                    all      0.842          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50      1.78G     0.4768          1        512: 100% 210/210 [01:24<00:00,  2.47it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:07<00:00,  1.99it/s]
#                    all      0.867          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50       1.8G     0.3606          1        512: 100% 210/210 [01:24<00:00,  2.50it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.54it/s]
#                    all      0.906          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50       1.8G     0.3155          1        512: 100% 210/210 [01:26<00:00,  2.42it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.66it/s]
#                    all      0.913          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50       1.8G     0.2439          1        512: 100% 210/210 [01:24<00:00,  2.50it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.63it/s]
#                    all      0.917          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50       1.8G     0.2529          1        512: 100% 210/210 [01:26<00:00,  2.43it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.81it/s]
#                    all      0.933          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50       1.8G     0.1983          1        512: 100% 210/210 [01:20<00:00,  2.61it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.76it/s]
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50       1.8G     0.1584          1        512: 100% 210/210 [01:23<00:00,  2.52it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.87it/s]
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50       1.8G     0.1683          1        512: 100% 210/210 [01:22<00:00,  2.55it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:07<00:00,  2.08it/s]
#                    all      0.906          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50       1.8G     0.1396          1        512: 100% 210/210 [01:26<00:00,  2.42it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.69it/s]
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50      1.81G     0.1333          1        512: 100% 210/210 [01:24<00:00,  2.50it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.69it/s]
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50       1.8G     0.1167          1        512: 100% 210/210 [01:26<00:00,  2.42it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:07<00:00,  1.95it/s]
#                    all      0.915          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50       1.8G     0.1032          1        512: 100% 210/210 [01:21<00:00,  2.58it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.68it/s]
#                    all      0.935          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50       1.8G     0.1069          1        512: 100% 210/210 [01:23<00:00,  2.53it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.70it/s]
#                    all      0.935          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50       1.8G    0.08686          1        512: 100% 210/210 [01:20<00:00,  2.60it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.69it/s]
#                    all      0.933          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50       1.8G    0.08938          1        512: 100% 210/210 [01:26<00:00,  2.42it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.49it/s]
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50       1.8G    0.08011          1        512: 100% 210/210 [01:23<00:00,  2.51it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.68it/s]
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50       1.8G    0.06741          1        512: 100% 210/210 [01:26<00:00,  2.43it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.32it/s]
#                    all      0.935          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50      1.81G    0.06428          1        512: 100% 210/210 [01:22<00:00,  2.53it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.29it/s]
#                    all       0.94          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50       1.8G    0.06598          1        512: 100% 210/210 [01:23<00:00,  2.51it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.83it/s]
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50      1.81G    0.06691          1        512: 100% 210/210 [01:19<00:00,  2.64it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.78it/s]
#                    all      0.915          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50       1.8G    0.06802          1        512: 100% 210/210 [01:27<00:00,  2.41it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.65it/s]
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50      1.81G    0.05429          1        512: 100% 210/210 [01:23<00:00,  2.51it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.55it/s]
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50       1.8G    0.07358          1        512: 100% 210/210 [01:26<00:00,  2.42it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.67it/s]
#                    all       0.94          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50      1.81G    0.04932          1        512: 100% 210/210 [01:23<00:00,  2.51it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.69it/s]
#                    all       0.95          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50       1.8G    0.05083          1        512: 100% 210/210 [01:27<00:00,  2.40it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.19it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50       1.8G    0.04341          1        512: 100% 210/210 [01:20<00:00,  2.59it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.69it/s]
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50       1.8G    0.04379          1        512: 100% 210/210 [01:23<00:00,  2.50it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:07<00:00,  1.93it/s]
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50       1.8G    0.04506          1        512: 100% 210/210 [01:22<00:00,  2.54it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.19it/s]
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50      1.79G    0.02765          1        512: 100% 210/210 [01:26<00:00,  2.44it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.73it/s]
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50      1.81G    0.03222          1        512: 100% 210/210 [01:24<00:00,  2.48it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.63it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50       1.8G    0.03461          1        512: 100% 210/210 [01:26<00:00,  2.44it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:07<00:00,  2.04it/s]
#                    all       0.95          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50      1.81G    0.02765          1        512: 100% 210/210 [01:20<00:00,  2.61it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.71it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50       1.8G    0.02791          1        512: 100% 210/210 [01:23<00:00,  2.52it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:09<00:00,  1.64it/s]
#                    all      0.956          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50       1.8G     0.0235          1        512: 100% 210/210 [01:20<00:00,  2.62it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.71it/s]
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50       1.8G    0.03903          1        512: 100% 210/210 [01:25<00:00,  2.45it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.15it/s]
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50      1.81G    0.02424          1        512: 100% 210/210 [01:22<00:00,  2.55it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.42it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50       1.8G    0.02549          1        512: 100% 210/210 [01:26<00:00,  2.43it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.65it/s]
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50       1.8G      0.023          1        512: 100% 210/210 [01:24<00:00,  2.49it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.51it/s]
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50       1.8G    0.02016          1        512: 100% 210/210 [01:27<00:00,  2.41it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.69it/s]
#                    all      0.952          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50       1.8G    0.02993          1        512: 100% 210/210 [01:19<00:00,  2.63it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.75it/s]
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50       1.8G    0.01696          1        512: 100% 210/210 [01:27<00:00,  2.40it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.68it/s]
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50       1.8G    0.02989          1        512: 100% 210/210 [01:23<00:00,  2.51it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.58it/s]
#                    all       0.95          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50       1.8G    0.01874          1        512: 100% 210/210 [01:25<00:00,  2.44it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.62it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50       1.8G    0.03638          1        512: 100% 210/210 [01:23<00:00,  2.51it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.35it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50       1.8G    0.02034          1        512: 100% 210/210 [01:25<00:00,  2.47it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.70it/s]
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50       1.8G    0.01729          1        512: 100% 210/210 [01:21<00:00,  2.57it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.80it/s]
#                    all      0.952          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50       1.8G    0.01948          1        512: 100% 210/210 [01:25<00:00,  2.44it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:06<00:00,  2.24it/s]
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50       1.8G    0.02515          1        512: 100% 210/210 [01:24<00:00,  2.48it/s]
#                classes   top1_acc   top5_acc: 100% 15/15 [00:05<00:00,  2.61it/s]
#                    all      0.956          1
#
# 50 epochs completed in 1.287 hours.
# Optimizer stripped from runs/classify/train/weights/last.pt, 10.3MB
# Optimizer stripped from runs/classify/train/weights/best.pt, 10.3MB
#
# Validating runs/classify/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-cls summary (fused): 73 layers, 5,081,605 parameters, 0 gradients, 12.5 GFLOPs
# train: /content/data-main/train... found 3345 images in 5 classes ✅
# val: /content/data-main/val... found 480 images in 5 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% 15/15 [00:08<00:00,  1.67it/s]
#                    all       0.96          1
# Speed: 0.4ms preprocess, 2.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train
# Results saved to runs/classify/train
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  lr/pg0 ▃▆███▇▇▇▇▇▇▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:                  lr/pg1 ▃▆███▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:                  lr/pg2 ▃▆███▇▇▇▇▇▇▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:   metrics/accuracy_top1 ▁▁▃▅▅▆▆▆▅▆▅▇▇▆▆▇▇▇▅▇▇▇▇▇▇▇▇▇██▇████▇▇▇██
# wandb:   metrics/accuracy_top5 ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:              train/loss █▄▄▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                val/loss █▆▅▃▃▂▂▃▂▂▂▂▂▂▂▂▁▂▂▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 2e-05
# wandb:                  lr/pg1 2e-05
# wandb:                  lr/pg2 2e-05
# wandb:   metrics/accuracy_top1 0.96042
# wandb:   metrics/accuracy_top5 1
# wandb:            model/GFLOPs 12.591
# wandb:        model/parameters 5087141
# wandb: model/speed_PyTorch(ms) 1.832
# wandb:              train/loss 0.02515
# wandb:                val/loss 0.95137
# wandb:
# wandb: 🚀 View run train at: https://wandb.ai/soyokaze83-universitas-indonesia/YOLOv8/runs/6zlvahan
# wandb: ⭐️ View project at: https://wandb.ai/soyokaze83-universitas-indonesia/YOLOv8
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 15 other file(s)
# wandb: Find logs at: ./wandb/run-20241221_141506-6zlvahan/logs
# 💡 Learn more at https://docs.ultralytics.com/modes/train
